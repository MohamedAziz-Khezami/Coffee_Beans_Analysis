# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedAziz-Khezami/Coffee_Beans_Analysis/blob/main/Coffe_Beans_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![c.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #**Introduction**
# This project focuses on analyzing coffee bean sales for **Golden Bloom Beans** , customer demographics, and product performance to provide actionable insights for improving business operations and customer satisfaction.
# ##**Objectives**
# * Which coffee products generate the highest revenue and profit?
# * Customer buying behavior by region, city, or loyalty status?
# * Trends in order frequency and quantity over time?
# *Sales forecasting?
#
#
# ##**Goals**
# * Increase Revenue: Identify the most profitable products and focus on promoting them.
# * Enhance Customer Retention: Analyze loyalty program data to improve customer satisfaction.
# * Optimize Inventory Management: Understand product demand patterns to ensure efficient stock levels.
# *Expanding the company's presence in the market.
#
# ##**Deliverables**
# * Power BI Dashboard.
# *Recommendations Report.
# *Forecasting machine learning model.

# %% [markdown]
# ## **Data Extraction**
# ---

# %%
# !pip install flaml
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.2/314.2 kB 4.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from prophet import Prophet
from flaml import AutoML
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Importing raw data for cleaning
# ### 1. **df_customers**:
#
#  This table contains data about the customers of the coffee business. It helps track customer demographics and their participation in the loyalty program.
#
#  Column Name	Description	Example
#  * **customer_id**:	Unique identifier for each customer.
#  * **customer_name**	: Full name of the customer.
#  * **address_line** :	The address of the customer (optional).
#  * **city** : The city where the customer resides.
#  * **country**:	The country of the customer.
#  * **postcode**:	Postal or ZIP code of the customer's address.
#  * **loyalty_card**:	Indicates if the customer has a loyalty card (TRUE for yes, FALSE for no).
#
# ### 2. **df_products**:
#
#  This table contains details about the coffee products offered by the business, including their types, sizes, prices, and profitability.
#
#
# * **product_id**:	Unique identifier for each product.
# * **coffee_type**:	The type of coffee .
#
#  *Ara: Arabica*
#
#  *Exc: Excelsa*
#
#  *Lib: Liberica*
#
#  *Rob: Robusta *
# * **roast_type**:	The roast level of the coffee (e.g., light, medium, dark).
# * **size package**: size of the product in kilograms.
# * **unit_price**:	Price of one unit of the product.
# * **price_per_100g**:	Price for 100 grams of the product, helpful for comparison.
# * **profit**:	Profit margin for the product per unit sold.
#
# ### **3. df_Orders**:
#
# This table records all customer orders, linking customers to products and capturing order details like date, quantity, and associated products.
#
#
# * **order_id**:	Unique identifier for each order.
#
# * **order_date**:	The date when the order was placed.
#
# * **customer_id**:	Identifier linking the order to the specific customer (customers.customer_id).
#
# * **product_id**:	Identifier linking the order to the specific product (products.product_id).
#
# * **quantity**:	Number of units of the product ordered.

# %%
df_customers = pd.read_csv('/content/drive/MyDrive/project bi/customers2.csv', delimiter=';')
df_products = pd.read_excel('/content/drive/MyDrive/project bi/products.xlsx')
df_orders = pd.read_csv('/content/drive/MyDrive/project bi/orders.csv' , delimiter=";")

# %% [markdown]
# ## Customers Table Cleaning
# ---
#
# 1.  We handled missing values.
# 2.  We dropped irrelevant columns.
# 3.  We handled misrepresented data types.
# 4. We reset the indexes

# %%
df_customers.head()
# Out:
#       Customer ID        Customer Name                 Email  \
# 0  17670-51384-MA       Aloisia Allner     aallner0@lulu.com
# 1  73342-18763-UW           Piotr Bote       pbote1@yelp.com
# 2  21125-22134-PX        Jami Redholes  jredholes2@tmall.com
# 3  71253-00052-RN           Dene Azema  dazema3@facebook.com
# 4  23806-46781-OU  Christoffer O' Shea                   NaN
#
#           Phone Number             Address Line 1         City        Country  \
# 0    +1 (862) 817-0124    57999 Pepper Wood Alley     Paterson  United States
# 1  +353 (913) 396-4653         2112 Ridgeway Hill      Crumlin        Ireland
# 2    +1 (210) 986-6806        5214 Bartillon Park  San Antonio  United States
# 3    +1 (217) 418-0714           27 Maywood Place  Springfield  United States
# 4  +353 (698) 362-9201  38980 Manitowish Junction   Cill Airne        Ireland
#
#   Postcode Loyalty Card
# 0     7505          Yes
# 1      D6W           No
# 2    78205          Yes
# 3    62711          Yes
# ...

# %%
df_customers.tail()
# Out:
#         Customer ID      Customer Name                    Email  \
# 995  43014-53743-XK   Jennica Tewelson  jtewelsonrn@samsung.com
# 996  62494-09113-RP  Marguerite Graves                      NaN
# 997  10940-42739-ET      Etan Featenby                      NaN
# 998  64965-78386-MY     Nicolina Jenny   njennyrq@bigcartel.com
# 999  77131-58092-GE  Vidovic Antonelli                      NaN
#
#            Phone Number           Address Line 1              City  \
# 995   +1 (469) 573-8379      4040 Hoard Junction            Dallas
# 996   +1 (479) 204-9111          91413 Scott Way        Fort Smith
# 997   +1 (719) 416-9560          885 Toban Plaza  Colorado Springs
# 998   +1 (562) 679-4750  6099 American Ash Court          Whittier
# 999  +44 (810) 927-9266        3242 Corscot Pass            London
#
#             Country Postcode Loyalty Card
# 995   United States    75210           No
# 996   United States    72905           No
# 997   United States    80920          Yes
# ...

# %%
df_customers.describe(include='all')
# Out:
#            Customer ID   Customer Name              Email       Phone Number  \
# count             1000            1000                796                870
# unique            1000            1000                796                870
# top     17670-51384-MA  Aloisia Allner  aallner0@lulu.com  +1 (862) 817-0124
# freq                 1               1                  1                  1
#
#                  Address Line 1        City        Country Postcode  \
# count                      1000        1000            989     1000
# unique                     1000         386              3      629
# top     57999 Pepper Wood Alley  Washington  United States      D04
# freq                          1          27            776       12
#
#        Loyalty Card
# count           992
# unique            2
# top              No
# freq            508

# %%
df_customers.shape
# Out:
# (1000, 9)

# %% [markdown]
# The `shape` function returns the dimensions of the given DataFrame, providing the number of rows and columns.

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer ID     1000 non-null   object
#  1   Customer Name   1000 non-null   object
#  2   Email           796 non-null    object
#  3   Phone Number    870 non-null    object
#  4   Address Line 1  1000 non-null   object
#  5   City            1000 non-null   object
#  6   Country         989 non-null    object
#  7   Postcode        1000 non-null   object
#  8   Loyalty Card    992 non-null    object
# dtypes: object(9)
# memory usage: 70.4+ KB

# %%
df_customers.isnull().sum()
# Out:
# Customer ID         0
# Customer Name       0
# Email             204
# Phone Number      130
# Address Line 1      0
# City                0
# Country            11
# Postcode            0
# Loyalty Card        8
# dtype: int64

# %% [markdown]
# ##Dropping Unnecessary Columns:
# Using the `sum` function, the total number of missing values in the dataset was identified. Subsequently, redundant columns such as Email and Phone Number were removed to optimize the dataset and focus on the most relevant attributes for analysis.

# %%
df_customers.drop(columns=['Email', 'Phone Number'], inplace=True)

# %% [markdown]
# ## adding missing Values:
# The `fillna` function was utilized to address missing values in the Country column, ensuring the dataset is more complete and better prepared for analysis.

# %%
#Countries missing values handeling
city_to_country = {
    'Provo': 'United States',
    'Saint Paul': 'United States',
    'Wootton': 'United Kingdom',
    'Cherryville': 'United States',
    'Whittier': 'United States',
    'Orlando': 'United States',
    'Twyford': 'United Kingdom',
    'Daingean': 'Ireland',
    'Mobile': 'United States',
    'San Francisco': 'United States',
    'Watergrasshill': 'Ireland'
}
df_customers['Country'] = df_customers['Country'].fillna(df_customers['City'].map(city_to_country))

# %% [markdown]
# the `mode()` function was used to determine the most frequently occurring value in the Loyalty Card column for each specified country (United States, United Kingdom, and Ireland).
# the `apply()` function was used in combination with `lambda` function to fill missing values in the Loyalty Card column, thus assigning the most frequent loalty card value **(if missing)** based on the country.
#
#
#
# >This ensures that missing data is imputed meaningfully while preserving the existing information.

# %%
#Loyalty card missing values handelling

most_freq_us = df_customers[df_customers['Country'] == 'United States']['Loyalty Card'].mode()[0]
most_freq_uk = df_customers[df_customers['Country'] == 'United Kingdom']['Loyalty Card'].mode()[0]
most_freq_ir = df_customers[df_customers['Country'] == 'Ireland']['Loyalty Card'].mode()[0]


df_customers['Loyalty Card'] = df_customers.apply(
    lambda row: most_freq_us if pd.isnull(row['Loyalty Card']) and row['Country'] == 'United States' else
    most_freq_uk if pd.isnull(row['Loyalty Card']) and row['Country'] == 'United Kingdom' else
    most_freq_ir if pd.isnull(row['Loyalty Card']) and row['Country'] == 'Ireland' else
    row['Loyalty Card'],
    axis=1
)

# %% [markdown]
# The *Loyalty Card* column was converted from an **object** to a **boolean** format to simplify analysis.

# %%
#changing to boolean
df_customers['Loyalty Card'] = df_customers['Loyalty Card'].apply(lambda x: True if x == 'Yes' else False)

# %%
df_customers.isnull().sum()
# Out:
# Customer ID       0
# Customer Name     0
# Address Line 1    0
# City              0
# Country           0
# Postcode          0
# Loyalty Card      0
# dtype: int64

# %%
df_customers.apply(lambda col: col.duplicated().any(), axis=0)
# Out:
# Customer ID       False
# Customer Name     False
# Address Line 1    False
# City               True
# Country            True
# Postcode           True
# Loyalty Card       True
# dtype: bool

# %% [markdown]
# ## Resetting Index and Sorting:
# The `reset_index` function was used to ensure sequential and clean indexing following data cleaning operations.
#
# Using the `sort_values()` function allows us to sort the `df_customers` DataFrame based on the values in the 'Customer ID' column. By setting the `inplace=True` argument, the DataFrame is directly modified, and the rows are reordered in ascending order according to the 'Customer ID'. This method helps in organizing data efficiently without creating a new DataFrame.

# %%
df_customers.reset_index(drop=True, inplace=True)

# %%
df_customers.sort_values(by='Customer ID', inplace=True)

# %%
df_customers.head()
# Out:
#         Customer ID       Customer Name       Address Line 1            City  \
# 690  00246-15080-LE   Francesco Dressel        1 Fulton Road          Toledo
# 168  00256-19905-YG  Stanislaus Valsler  95 Southridge Alley    Castlebridge
# 628  00445-42781-KX      Faunie Brigham      7246 Green Pass       Castlerea
# 101  00539-42510-RY       Nickey Youles    12461 Dryden Pass  Edgeworthstown
# 925  00841-75330-ZV          Rori Ollin    05889 Heath Place        Pasadena
#
#            Country Postcode  Loyalty Card
# 690  United States    43605         False
# 168        Ireland      R14         False
# 628        Ireland      F45          True
# 101        Ireland      E25          True
# 925  United States    91199          True

# %% [markdown]
# ## Products Table Cleaning
# ---

# %%
df_products.head()
# Out:
#   Product ID Coffee Type Roast Type  Size  Unit Price  Price per 100g   Profit
# 0    A-L-0.2         Ara          L   0.2       3.885          1.9425  0.34965
# 1    A-L-0.5         Ara          L   0.5       7.770          1.5540  0.69930
# 2      A-L-1         Ara          L   1.0      12.950          1.2950  1.16550
# 3    A-L-2.5         Ara          L   2.5      29.785          1.1914  2.68065
# 4    A-M-0.2         Ara          M   0.2       3.375          1.6875  0.30375

# %%
df_products.tail()
# Out:
#    Product ID Coffee Type Roast Type  Size  Unit Price  Price per 100g  \
# 43    E-M-2.5         Exc          M   2.5      31.625          1.2650
# 44    E-D-0.2         Exc          D   0.2       3.645          1.8225
# 45    E-D-0.5         Exc          D   0.5       7.290          1.4580
# 46      E-D-1         Exc          D   1.0      12.150          1.2150
# 47    E-D-2.5         Exc          D   2.5      27.945          1.1178
#
#      Profit
# 43  3.47875
# 44  0.40095
# 45  0.80190
# 46  1.33650
# 47  3.07395

# %%
df_products.describe(include='all')
# Out:
#        Product ID Coffee Type Roast Type       Size  Unit Price  \
# count          48          48         48  48.000000   48.000000
# unique         48           4          3        NaN         NaN
# top       A-L-0.2         Ara          L        NaN         NaN
# freq            1          12         16        NaN         NaN
# mean          NaN         NaN        NaN   1.050000   13.046250
# std           NaN         NaN        NaN   0.893951    9.953578
# min           NaN         NaN        NaN   0.200000    2.685000
# 25%           NaN         NaN        NaN   0.425000    5.216250
# 50%           NaN         NaN        NaN   0.750000    9.230000
# 75%           NaN         NaN        NaN   1.375000   17.033750
# max           NaN         NaN        NaN   2.500000   36.455000
#
#         Price per 100g     Profit
# count        48.000000  48.000000
# unique             NaN        NaN
# top                NaN        NaN
# freq               NaN        NaN
# ...

# %%
df_products.shape
# Out:
# (48, 7)

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Product ID      48 non-null     object
#  1   Coffee Type     48 non-null     object
#  2   Roast Type      48 non-null     object
#  3   Size            48 non-null     float64
#  4   Unit Price      48 non-null     float64
#  5   Price per 100g  48 non-null     float64
#  6   Profit          48 non-null     float64
# dtypes: float64(4), object(3)
# memory usage: 2.8+ KB

# %% [markdown]
# The `info()` function provides a summary of the DataFrame, including details about the data types, non-null values, and memory usage.
# > This information is crucial for understanding the structure and format of the dataset, enabling us to make informed decisions when modifying or processing the data.

# %%
df_products.isna().sum()
# Out:
# Product ID        0
# Coffee Type       0
# Roast Type        0
# Size              0
# Unit Price        0
# Price per 100g    0
# Profit            0
# dtype: int64

# %% [markdown]
# The `isna().sum()` function allows us to count the number of missing null values in each column of the **df_products** DataFrame.
#
# > In our case, we've got 0 null values, so there won't be any retaining, filling or removing any missing values, unlike in the previous Dataframe **df_customers**.

# %% [markdown]
# ## Orders Table Cleaning
# ---

# %%
df_orders.head()
# Out:
#         Order ID  Order Date     Customer ID Product ID  Quantity  \
# 0  QEV-37451-860  05/09/2019  17670-51384-MA      R-M-1         2
# 1  QEV-37451-860  05/09/2019  17670-51384-MA    E-M-0.5         5
# 2  FAA-43335-268  17/06/2021  21125-22134-PX      A-L-1         1
# 3  KAC-83089-793  15/07/2021  23806-46781-OU      E-M-1         2
# 4  KAC-83089-793  15/07/2021  23806-46781-OU    R-L-2.5         2
#
#    Customer Name  Email  Country  Coffee Type  Roast Type  Size  Unit Price  \
# 0            NaN    NaN      NaN          NaN         NaN   NaN         NaN
# 1            NaN    NaN      NaN          NaN         NaN   NaN         NaN
# 2            NaN    NaN      NaN          NaN         NaN   NaN         NaN
# 3            NaN    NaN      NaN          NaN         NaN   NaN         NaN
# 4            NaN    NaN      NaN          NaN         NaN   NaN         NaN
#
#    Sales
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
df_orders.tail()
# Out:
#           Order ID  Order Date     Customer ID Product ID  Quantity  \
# 995  RLM-96511-467  06/01/2020  43014-53743-XK    R-L-2.5         1
# 996  AEZ-13242-456  04/05/2022  62494-09113-RP    R-M-0.5         5
# 997  UME-75640-698  11/10/2019  62494-09113-RP    A-M-0.5         4
# 998  GJC-66474-557  03/08/2021  64965-78386-MY      A-D-1         1
# 999  IRV-20769-219  15/10/2020  77131-58092-GE    E-M-0.2         3
#
#      Customer Name  Email  Country  Coffee Type  Roast Type  Size  Unit Price  \
# 995            NaN    NaN      NaN          NaN         NaN   NaN         NaN
# 996            NaN    NaN      NaN          NaN         NaN   NaN         NaN
# 997            NaN    NaN      NaN          NaN         NaN   NaN         NaN
# 998            NaN    NaN      NaN          NaN         NaN   NaN         NaN
# 999            NaN    NaN      NaN          NaN         NaN   NaN         NaN
#
#      Sales
# 995    NaN
# 996    NaN
# 997    NaN
# 998    NaN
# 999    NaN

# %%
df_orders.describe(include='all')
# Out:
#              Order ID  Order Date     Customer ID Product ID     Quantity  \
# count            1000        1000            1000       1000  1000.000000
# unique            957         689             913         48          NaN
# top     NOP-21394-646  27/04/2019  86579-92122-OC    A-M-0.5          NaN
# freq                5           7               7         30          NaN
# mean              NaN         NaN             NaN        NaN     3.551000
# std               NaN         NaN             NaN        NaN     1.681733
# min               NaN         NaN             NaN        NaN     1.000000
# 25%               NaN         NaN             NaN        NaN     2.000000
# 50%               NaN         NaN             NaN        NaN     4.000000
# 75%               NaN         NaN             NaN        NaN     5.000000
# max               NaN         NaN             NaN        NaN     6.000000
#
#         Customer Name  Email  Country  Coffee Type  Roast Type  Size  \
# ...

# %% [markdown]
# The `describe` function generates a summary of the **df_orders** DataFrame, providing descriptive statistics for all columns, including both numerical and categorical data.
#
# When the `include='all'` parameter is specified, it ensures that statistics such as **mean**, **standard deviation**, **min**, **max**, and **quartiles** for numerical columns, as well as the **count**, **unique values**, **top**, and **frequency** for categorical columns, are all included.

# %%
df_orders.shape
# Out:
# (1000, 13)

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       1000 non-null   object
#  1   Order Date     1000 non-null   object
#  2   Customer ID    1000 non-null   object
#  3   Product ID     1000 non-null   object
#  4   Quantity       1000 non-null   int64
#  5   Customer Name  0 non-null      float64
#  6   Email          0 non-null      float64
#  7   Country        0 non-null      float64
#  8   Coffee Type    0 non-null      float64
#  9   Roast Type     0 non-null      float64
#  10  Size           0 non-null      float64
#  11  Unit Price     0 non-null      float64
#  12  Sales          0 non-null      float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 101.7+ KB

# %%
df_orders.isna().sum()
# Out:
# Order ID            0
# Order Date          0
# Customer ID         0
# Product ID          0
# Quantity            0
# Customer Name    1000
# Email            1000
# Country          1000
# Coffee Type      1000
# Roast Type       1000
# Size             1000
# Unit Price       1000
# Sales            1000
# dtype: int64

# %%
df_orders.apply(lambda col: col.duplicated().any(), axis=0)
# Out:
# Order ID         True
# Order Date       True
# Customer ID      True
# Product ID       True
# Quantity         True
# Customer Name    True
# Email            True
# Country          True
# Coffee Type      True
# Roast Type       True
# Size             True
# Unit Price       True
# Sales            True
# dtype: bool

# %%
df_orders = df_orders.iloc[:, 0:5]
df_orders.head()
# Out:
#         Order ID  Order Date     Customer ID Product ID  Quantity
# 0  QEV-37451-860  05/09/2019  17670-51384-MA      R-M-1         2
# 1  QEV-37451-860  05/09/2019  17670-51384-MA    E-M-0.5         5
# 2  FAA-43335-268  17/06/2021  21125-22134-PX      A-L-1         1
# 3  KAC-83089-793  15/07/2021  23806-46781-OU      E-M-1         2
# 4  KAC-83089-793  15/07/2021  23806-46781-OU    R-L-2.5         2

# %% [markdown]
# The code `df_orders.iloc[:, 0:5]` selects the first five columns from the **df_orders** DataFrame using the `.iloc` indexer. It slices the DataFrame to retain only these columns, effectively modifying the DataFrame to include just the first five columns.

# %%
# Changing the order date from the object format to the date format
df_orders['Order Date'] = pd.to_datetime(df_orders['Order Date'] , format='%d/%m/%Y' , dayfirst=True)
df_orders.head()
# Out:
#         Order ID Order Date     Customer ID Product ID  Quantity
# 0  QEV-37451-860 2019-09-05  17670-51384-MA      R-M-1         2
# 1  QEV-37451-860 2019-09-05  17670-51384-MA    E-M-0.5         5
# 2  FAA-43335-268 2021-06-17  21125-22134-PX      A-L-1         1
# 3  KAC-83089-793 2021-07-15  23806-46781-OU      E-M-1         2
# 4  KAC-83089-793 2021-07-15  23806-46781-OU    R-L-2.5         2

# %% [markdown]
# >After running this, the **Order Date** column will be in proper datetime format, making it easier to perform time-based operations or analysis.

# %%
df_orders.sort_values(by='Order Date', inplace=True, ascending=True)
df_orders.reset_index(drop=True, inplace=True)
df_orders.head()
# Out:
#         Order ID Order Date     Customer ID Product ID  Quantity
# 0  CTE-31437-326 2019-01-02  22721-63196-UJ    E-M-0.2         4
# 1  CTE-31437-326 2019-01-02  22721-63196-UJ    L-L-0.2         3
# 2  CTE-31437-326 2019-01-02  22721-63196-UJ      L-D-1         4
# 3  CTE-31437-326 2019-01-02  22721-63196-UJ    R-M-0.2         4
# 4  EZT-46571-659 2019-01-02  03396-68805-ZC    R-M-0.5         3

# %% [markdown]
# The code `sorts` the **df_orders** DataFrame by **Order Date** in ascending order and resets the index using the `reset_index` function to ensure the correct sequence.

# %% [markdown]
# # **Connecting azure mysql server to the python app**
# ---

# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.0/34.0 MB 27.5 MB/s eta 0:00:00
# ...

# %%
import mysql.connector

# Define connection parameters
cnx = mysql.connector.connect(
    user="adminproject",  #  Azure MySQL username
    password="Projectbi123",  #  Azure MySQL password
    host="biserver.mysql.database.azure.com",  #  Azure MySQL server
    port=3306,  # Default MySQL port
    database="coffee",  # Name of your database
    ssl_disabled=False  # SSL must not be disabled for Azure MySQL
)

# Test connection
if cnx.is_connected():
    print("Connection successful!")
else:
    print("Connection failed!")


cursor = cnx.cursor()
# Out:
# Connection successful!

# %% [markdown]
# The code connects to an Azure MySQL database using `mysql.connector`, with parameters like username, password, host, port, and database name. It tests the connection and prints a `success` or `failure` message like displayed above.
#
# It also creates a `cursor` for executing SQL queries which is used to execute SQL commands and **retrieve**, **manipulate**, or **iterate** over the data returned by those queries.

# %% [markdown]
# The error is due to the data being already uploaded to the azure cloud database.

# %%
# Define the table name
table_name = "customers"

# Create an insert query template
insert_query = f"""
    INSERT INTO {table_name} (customer_id, customer_name, address_line, city, country, postcode, loyalty_card)
    VALUES (%s, %s, %s, %s, %s, %s ,%s)
"""

# Upload DataFrame to MySQL
for _, row in df_customers.iterrows():
    cursor.execute(insert_query, tuple(row))

# Commit the transaction
cnx.commit()
print(f"{len(df_customers)} rows inserted into {table_name} table.")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-42-689639cd3d39> in <cell line: 0>()
#      10 # Upload DataFrame to MySQL
#      11 for _, row in df_customers.iterrows():
# ---> 12     cursor.execute(insert_query, tuple(row))
#      13
#      14 # Commit the transaction
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/cursor.py in execute(self, operation, params, map_results)
#     414
#     415         self._handle_result(
# --> 416             self._connection.cmd_query(
#     417                 self._stmt_partition["mappable_stmt"],
#     418                 read_timeout=self._read_timeout,
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/opentelemetry/context_propagation.py in wrapper(cnx, *args, **kwargs)
#     104
#     105         try:
# --> 106             result = method(cnx, *args, **kwargs)
#     107         finally:
# ...

# %%
# Define the table name
table_name = "products"

# Create an insert query template
insert_query = f"""
    INSERT INTO {table_name} (product_id, coffee_type, roast_type, size, unit_price, price_per_100g, profit)
    VALUES (%s, %s, %s, %s, %s, %s, %s)
"""

# Upload DataFrame to MySQL
for _, row in df_products.iterrows():

    cursor.execute(insert_query, tuple(row))

# Commit the transaction
cnx.commit()
print(f"{len(df_products)} rows inserted into {table_name} table.")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-44-0c83e3fa6b76> in <cell line: 0>()
#      11 for _, row in df_products.iterrows():
#      12
# ---> 13     cursor.execute(insert_query, tuple(row))
#      14
#      15 # Commit the transaction
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/cursor.py in execute(self, operation, params, map_results)
#     414
#     415         self._handle_result(
# --> 416             self._connection.cmd_query(
#     417                 self._stmt_partition["mappable_stmt"],
#     418                 read_timeout=self._read_timeout,
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/opentelemetry/context_propagation.py in wrapper(cnx, *args, **kwargs)
#     104
#     105         try:
# --> 106             result = method(cnx, *args, **kwargs)
#     107         finally:
# ...

# %%
# Define the table name
table_name = "orders"

# Create an insert query template
insert_query = f"""
    INSERT INTO {table_name} (order_id, order_date, customer_id, product_id, quantity)
    VALUES (%s, %s, %s, %s, %s)
"""

# Upload DataFrame to MySQL
for _, row in df_orders.iterrows():
    row['Order Date'] = row['Order Date'].strftime('%Y-%m-%d %H:%M:%S')  # Convert to string
    cursor.execute(insert_query, tuple(row))

# Commit the transaction
cnx.commit()
print(f"{len(df_orders)} rows inserted into {table_name} table.")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-45-d15a14fbd262> in <cell line: 0>()
#      11 for _, row in df_orders.iterrows():
#      12     row['Order Date'] = row['Order Date'].strftime('%Y-%m-%d %H:%M:%S')  # Convert to string
# ---> 13     cursor.execute(insert_query, tuple(row))
#      14
#      15 # Commit the transaction
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/cursor.py in execute(self, operation, params, map_results)
#     414
#     415         self._handle_result(
# --> 416             self._connection.cmd_query(
#     417                 self._stmt_partition["mappable_stmt"],
#     418                 read_timeout=self._read_timeout,
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/opentelemetry/context_propagation.py in wrapper(cnx, *args, **kwargs)
#     104
#     105         try:
# ...

# %% [markdown]
# Above, we insert data from three pandas DataFrames (**df_customers**,**df_products** and **df_orders**) into MySQL tables (**customers**, **products** and **orders**)
#
# We use a loop to execute `INSERT` queries for each row of the DataFrames, transferring the data into the respective MySQL tables. After inserting all rows, we commit the changes to the database and print the number of rows successfully inserted.
